# %% [markdown]
# # Project-1
# ## Using Amazon Fine Food Reviews Dataset

# %%
import numpy as np
import pandas as pd

# %%
ds_food = pd.read_csv("retail.csv")

# %%
ds_food
# Out:
#     Transaction_ID  Customer_ID     Product         Category    Price  \
# 0             1000         2102      Laptop      Accessories   905.01
# 1             1001         2435     Speaker  Home Appliances   796.35
# 2             1002         2860          TV  Home Appliances  1854.05
# 3             1003         2270  Smartwatch      Accessories      NaN
# 4             1004         2106     Speaker  Home Appliances   659.82
# ..             ...          ...         ...              ...      ...
# 95            1095         2821      Laptop      Accessories  1953.46
# 96            1096         2476     Speaker      Electronics   827.96
# 97            1097         2702  Headphones      Accessories      NaN
# 98            1098         2401      Camera  Home Appliances   696.69
# 99            1099         2729       Phone      Accessories  1272.36
#
#     Quantity  Total_Amount
# 0        2.0       1810.02
# 1        2.0       1592.70
# 2        1.0       1854.05
# ...

# %%
ds_food.isnull().sum()
# Out:
# Transaction_ID     0
# Customer_ID        0
# Product            0
# Category           0
# Price             20
# Quantity          18
# Total_Amount       0
# dtype: int64
